# %%
from IPython.core.display import HTML

# Create an HTML button with a link to www.databricks.com
button_html = """
<button onclick="window.open('https://signup.databricks.com/?l=en-US&dbx_source=www', '_blank')"
        style="background-color: #4CAF50; color: white; border: none; padding: 10px 20px; text-align: center; text-decoration: none; font-size: 16px; border-radius: 5px; cursor: pointer;">
    Go to Databricks
</button>
"""

# Display the button in the Jupyter Notebook
HTML(button_html)
# Out:
# <button onclick="window.open('https://signup.databricks.com/?l=en-US&dbx_source=www', '_blank')"
#         style="background-color: #4CAF50; color: white; border: none; padding: 10px 20px; text-align: center; text-decoration: none; font-size: 16px; border-radius: 5px; cursor: pointer;">
#     Go to Databricks
# </button>

# %%
import pandas as pd

# %%
import requests

r = requests.get("https://www.imf.org/external/datamapper/api/v1/NGDP_RPCH")
raw = r.json()['values']
print(raw)

# %%
raw_df = pd.DataFrame.from_dict(raw['NGDP_RPCH'], orient='index')
raw_df
# Out:
#      1980  1981  1982  1983  1984  1985  ...  2024  2025  2026  2027  2028  2029
# SDN   2.5   6.3   4.1  -1.5  -5.6  -0.6  ... -20.3   8.3  13.5   6.9   5.7   4.5
# SLV  -8.6  -5.7  -6.3   1.5   1.3   0.6  ...   3.0   3.0   2.8   2.8   2.8   2.8
# SWZ  -3.8   6.9   1.4  -0.5   2.5   1.9  ...   4.6   4.2   3.4   2.9   2.7   2.6
# FJI  -1.7   6.0  -1.1  -4.2  10.1  -3.8  ...   3.0   3.4   3.4   3.3   3.3   3.1
# FIN   5.7   1.3   3.1   3.1   3.2   3.5  ...  -0.2   2.0   1.8   1.7   1.6   1.5
# ..    ...   ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...
# MAC   NaN   NaN   NaN   NaN   NaN   NaN  ...  10.6   7.3   4.4   3.2   3.0   3.0
# AFG   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# NRU   NaN   NaN   NaN   NaN   NaN   NaN  ...   1.5   1.4   1.6   1.6   0.8   1.8
# SOM   NaN   NaN   NaN   NaN   NaN   NaN  ...   4.0   4.0   4.1   4.1   4.3   4.5
# SSD   NaN   NaN   NaN   NaN   NaN   NaN  ... -26.4  27.2  25.0   4.9   4.9   4.9
#
# [228 rows x 50 columns]

# %%
df = raw_df.reset_index().melt(id_vars=['index'], var_name = 'year', value_name='gdp_growth')

# %%
def create_continent_mapping():
    continents = {
        'ASIA': [
            'BTN', 'CHN', 'HKG', 'IND', 'IDN', 'IRN', 'ISR', 'JPN', 'KOR', 'LAO', 
            'MDV', 'MNG', 'MMR', 'NPL', 'PAK', 'PHL', 'SGP', 'LKA', 'SYR', 'TWN', 
            'THA', 'VNM', 'BGD', 'BRN', 'KHM', 'MAC', 'MYS', 'TLS', 'AFG', 'IRQ',
            'YEM', 'BHR', 'KWT', 'OMN', 'QAT', 'SAU', 'ARE', 'JOR', 'LBN'
        ],
        'EUROPE': [
            'ALB', 'AUT', 'BEL', 'BGR', 'HRV', 'CYP', 'CZE', 'DNK', 'EST', 'FIN',
            'FRA', 'DEU', 'GRC', 'HUN', 'ISL', 'IRL', 'ITA', 'LVA', 'LTU', 'LUX',
            'MLT', 'NLD', 'NOR', 'POL', 'PRT', 'ROU', 'SVK', 'SVN', 'ESP', 'SWE',
            'CHE', 'GBR', 'BLR', 'MDA', 'RUS', 'UKR', 'AND', 'SMR', 'SRB', 'MNE',
            'BIH', 'MKD'
        ],
        'AFRICA': [
            'DZA', 'AGO', 'BEN', 'BWA', 'BFA', 'BDI', 'CMR', 'CPV', 'CAF', 'TCD',
            'COM', 'COG', 'COD', 'CIV', 'DJI', 'EGY', 'GNQ', 'ERI', 'ETH', 'GAB',
            'GMB', 'GHA', 'GIN', 'GNB', 'KEN', 'LSO', 'LBR', 'LBY', 'MDG', 'MWI',
            'MLI', 'MRT', 'MUS', 'MAR', 'MOZ', 'NAM', 'NER', 'NGA', 'RWA', 'STP',
            'SEN', 'SYC', 'SLE', 'SOM', 'ZAF', 'SSD', 'SDN', 'SWZ', 'TZA', 'TGO',
            'TUN', 'UGA', 'ZMB', 'ZWE'
        ],
        'NORTH_AMERICA': [
            'CAN', 'USA', 'MEX', 'BHS', 'BRB', 'CRI', 'CUB', 'DOM', 'SLV', 'GTM',
            'HTI', 'HND', 'JAM', 'NIC', 'PAN', 'TTO', 'BLZ', 'GRD', 'KNA', 'VCT',
            'ATG', 'DMA', 'LCA', 'PRI', 'ABW'
        ],
        'SOUTH_AMERICA': [
            'ARG', 'BOL', 'BRA', 'CHL', 'COL', 'ECU', 'GUY', 'PRY', 'PER', 'SUR',
            'URY', 'VEN'
        ],
        'OCEANIA': [
            'AUS', 'FJI', 'KIR', 'MHL', 'FSM', 'NRU', 'NZL', 'PLW', 'PNG', 'WSM',
            'SLB', 'TON', 'TUV', 'VUT'
        ]
    }
    
    # Create reverse mapping (country to continent)
    country_to_continent = {}
    for continent, countries in continents.items():
        for country in countries:
            country_to_continent[country] = continent
            
    # Add special cases/regions
    special_regions = {
        'WEOWORLD': 'WORLD',
        'EU': 'EUROPE',
        'EURO': 'EUROPE',
        'WE': 'EUROPE',
        'ADVEC': 'ADVANCED_ECONOMIES',
        'OEMDC': 'EMERGING_MARKETS',
        # Add other special cases as needed
    }
    country_to_continent.update(special_regions)
    
    return country_to_continent

# %%
create_continent_mapping()
# Out:
# {'BTN': 'ASIA',
#  'CHN': 'ASIA',
#  'HKG': 'ASIA',
#  'IND': 'ASIA',
#  'IDN': 'ASIA',
#  'IRN': 'ASIA',
#  'ISR': 'ASIA',
#  'JPN': 'ASIA',
#  'KOR': 'ASIA',
#  'LAO': 'ASIA',
#  'MDV': 'ASIA',
#  'MNG': 'ASIA',
#  'MMR': 'ASIA',
#  'NPL': 'ASIA',
#  'PAK': 'ASIA',
#  'PHL': 'ASIA',
#  'SGP': 'ASIA',
#  'LKA': 'ASIA',
#  'SYR': 'ASIA',
#  'TWN': 'ASIA',
#  'THA': 'ASIA',
#  'VNM': 'ASIA',
#  'BGD': 'ASIA',
#  'BRN': 'ASIA',
#  'KHM': 'ASIA',
#  'MAC': 'ASIA',
#  'MYS': 'ASIA',
#  'TLS': 'ASIA',
#  'AFG': 'ASIA',
#  'IRQ': 'ASIA',
#  'YEM': 'ASIA',
#  'BHR': 'ASIA',
#  'KWT': 'ASIA',
#  'OMN': 'ASIA',
#  'QAT': 'ASIA',
#  'SAU': 'ASIA',
#  'ARE': 'ASIA',
#  'JOR': 'ASIA',
#  'LBN': 'ASIA',
#  'ALB': 'EUROPE',
#  'AUT': 'EUROPE',
#  'BEL': 'EUROPE',
#  'BGR': 'EUROPE',
#  'HRV': 'EUROPE',
#  'CYP': 'EUROPE',
#  'CZE': 'EUROPE',
#  'DNK': 'EUROPE',
#  'EST': 'EUROPE',
#  'FIN': 'EUROPE',
#  'FRA': 'EUROPE',
#  'DEU': 'EUROPE',
#  'GRC': 'EUROPE',
#  'HUN': 'EUROPE',
#  'ISL': 'EUROPE',
#  'IRL': 'EUROPE',
#  'ITA': 'EUROPE',
#  'LVA': 'EUROPE',
#  'LTU': 'EUROPE',
#  'LUX': 'EUROPE',
#  'MLT': 'EUROPE',
#  'NLD': 'EUROPE',
#  'NOR': 'EUROPE',
#  'POL': 'EUROPE',
#  'PRT': 'EUROPE',
#  'ROU': 'EUROPE',
#  'SVK': 'EUROPE',
#  'SVN': 'EUROPE',
#  'ESP': 'EUROPE',
#  'SWE': 'EUROPE',
#  'CHE': 'EUROPE',
#  'GBR': 'EUROPE',
#  'BLR': 'EUROPE',
#  'MDA': 'EUROPE',
#  'RUS': 'EUROPE',
#  'UKR': 'EUROPE',
#  'AND': 'EUROPE',
#  'SMR': 'EUROPE',
#  'SRB': 'EUROPE',
#  'MNE': 'EUROPE',
#  'BIH': 'EUROPE',
#  'MKD': 'EUROPE',
#  'DZA': 'AFRICA',
#  'AGO': 'AFRICA',
#  'BEN': 'AFRICA',
#  'BWA': 'AFRICA',
#  'BFA': 'AFRICA',
#  'BDI': 'AFRICA',
#  'CMR': 'AFRICA',
#  'CPV': 'AFRICA',
#  'CAF': 'AFRICA',
#  'TCD': 'AFRICA',
#  'COM': 'AFRICA',
#  'COG': 'AFRICA',
#  'COD': 'AFRICA',
#  'CIV': 'AFRICA',
#  'DJI': 'AFRICA',
#  'EGY': 'AFRICA',
#  'GNQ': 'AFRICA',
#  'ERI': 'AFRICA',
#  'ETH': 'AFRICA',
#  'GAB': 'AFRICA',
#  'GMB': 'AFRICA',
#  'GHA': 'AFRICA',
#  'GIN': 'AFRICA',
#  'GNB': 'AFRICA',
#  'KEN': 'AFRICA',
#  'LSO': 'AFRICA',
#  'LBR': 'AFRICA',
#  'LBY': 'AFRICA',
#  'MDG': 'AFRICA',
#  'MWI': 'AFRICA',
#  'MLI': 'AFRICA',
#  'MRT': 'AFRICA',
#  'MUS': 'AFRICA',
#  'MAR': 'AFRICA',
#  'MOZ': 'AFRICA',
#  'NAM': 'AFRICA',
#  'NER': 'AFRICA',
#  'NGA': 'AFRICA',
#  'RWA': 'AFRICA',
#  'STP': 'AFRICA',
#  'SEN': 'AFRICA',
#  'SYC': 'AFRICA',
#  'SLE': 'AFRICA',
#  'SOM': 'AFRICA',
#  'ZAF': 'AFRICA',
#  'SSD': 'AFRICA',
#  'SDN': 'AFRICA',
#  'SWZ': 'AFRICA',
#  'TZA': 'AFRICA',
#  'TGO': 'AFRICA',
#  'TUN': 'AFRICA',
#  'UGA': 'AFRICA',
#  'ZMB': 'AFRICA',
#  'ZWE': 'AFRICA',
#  'CAN': 'NORTH_AMERICA',
#  'USA': 'NORTH_AMERICA',
#  'MEX': 'NORTH_AMERICA',
#  'BHS': 'NORTH_AMERICA',
#  'BRB': 'NORTH_AMERICA',
#  'CRI': 'NORTH_AMERICA',
#  'CUB': 'NORTH_AMERICA',
#  'DOM': 'NORTH_AMERICA',
#  'SLV': 'NORTH_AMERICA',
#  'GTM': 'NORTH_AMERICA',
#  'HTI': 'NORTH_AMERICA',
#  'HND': 'NORTH_AMERICA',
#  'JAM': 'NORTH_AMERICA',
#  'NIC': 'NORTH_AMERICA',
#  'PAN': 'NORTH_AMERICA',
#  'TTO': 'NORTH_AMERICA',
#  'BLZ': 'NORTH_AMERICA',
#  'GRD': 'NORTH_AMERICA',
#  'KNA': 'NORTH_AMERICA',
#  'VCT': 'NORTH_AMERICA',
#  'ATG': 'NORTH_AMERICA',
#  'DMA': 'NORTH_AMERICA',
#  'LCA': 'NORTH_AMERICA',
#  'PRI': 'NORTH_AMERICA',
#  'ABW': 'NORTH_AMERICA',
#  'ARG': 'SOUTH_AMERICA',
#  'BOL': 'SOUTH_AMERICA',
#  'BRA': 'SOUTH_AMERICA',
#  'CHL': 'SOUTH_AMERICA',
#  'COL': 'SOUTH_AMERICA',
#  'ECU': 'SOUTH_AMERICA',
#  'GUY': 'SOUTH_AMERICA',
#  'PRY': 'SOUTH_AMERICA',
#  'PER': 'SOUTH_AMERICA',
#  'SUR': 'SOUTH_AMERICA',
#  'URY': 'SOUTH_AMERICA',
#  'VEN': 'SOUTH_AMERICA',
#  'AUS': 'OCEANIA',
#  'FJI': 'OCEANIA',
#  'KIR': 'OCEANIA',
#  'MHL': 'OCEANIA',
#  'FSM': 'OCEANIA',
#  'NRU': 'OCEANIA',
#  'NZL': 'OCEANIA',
#  'PLW': 'OCEANIA',
#  'PNG': 'OCEANIA',
#  'WSM': 'OCEANIA',
#  'SLB': 'OCEANIA',
#  'TON': 'OCEANIA',
#  'TUV': 'OCEANIA',
#  'VUT': 'OCEANIA',
#  'WEOWORLD': 'WORLD',
#  'EU': 'EUROPE',
#  'EURO': 'EUROPE',
#  'WE': 'EUROPE',
#  'ADVEC': 'ADVANCED_ECONOMIES',
#  'OEMDC': 'EMERGING_MARKETS'}

# %%
df['continent'] = df['index'].map(create_continent_mapping())
df
# Out:
#       index  year  gdp_growth      continent
# 0       SDN  1980         2.5         AFRICA
# 1       SLV  1980        -8.6  NORTH_AMERICA
# 2       SWZ  1980        -3.8         AFRICA
# 3       FJI  1980        -1.7        OCEANIA
# 4       FIN  1980         5.7         EUROPE
# ...     ...   ...         ...            ...
# 11395   MAC  2029         3.0           ASIA
# 11396   AFG  2029         NaN           ASIA
# 11397   NRU  2029         1.8        OCEANIA
# 11398   SOM  2029         4.5         AFRICA
# 11399   SSD  2029         4.9         AFRICA
#
# [11400 rows x 4 columns]

# %%
display(df[df['year'] == '2024'])
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
E</td></tr><tr><td>NLD</td><td>1980</td><td>null</td><td>EUROPE</td></tr><tr><td>BLR</td><td>1980</td><td>null</td><td>EUROPE</td></tr><tr><td>RUS</td><td>1980</td><td>null</td><td>EUROPE</td></tr><tr><td>MDA</td><td>1980</td><td>null</td><td>EUROPE</td></tr><tr><td>EURO</td><td>1980</td><td>null</td><td>EUROPE</td></tr><tr><td>UKR</td><td>1980</td><td>null</td><td>EUROPE</td></tr><tr><td>HRV</td><td>1980</td><td>null</td><td>EUROPE</td></tr><tr><td>SVN</td><td>1980</td><td>null</td><td>EUROPE</td></tr><tr><td>MKD</td><td>1980</td><td>null</td><td>EUROPE</td></tr><tr><td>LVA</td><td>1980</td><td>null</td><td>EUROPE</td></tr><tr><td>EST</td><td>1980</td><td>null</td><td>EUROPE</td></tr><tr><td>SVK</td><td>1980</td><td>null</td><td>EUROPE</td></tr><tr><td>BIH</td><td>1980</td><td>null</td><td>EUROPE</td></tr><tr><td>LTU</td><td>1980</td><td>null</td><td>EUROPE</td></tr><tr><td>CZE</td><td>1980</td><td>null</td><td>EUROPE</td></tr><tr><td>SMR</td><td>1980</td><td>null</td><td>EUROPE</td></tr><tr><td>SRB</td><td>1980</td><td>null</td><td>EUROPE</td></tr><tr><td>AND</td><td>1980</td><td>null</td><td>EUROPE</td></tr><tr><td>MNE</td><td>1980</td><td>null</td><td>EUROPE</td></tr><tr><td>FIN</td><td>1981</td><td>1.3</td><td>EUROPE</td></tr><tr><td>GRC</td><td>1981</td><td>-1.6</td><td>EUROPE</td></tr><tr><td>HUN</td><td>1981</td><td>2.9</td><td>EUROPE</td></tr><tr><td>ISL</td><td>1981</td><td>4.3</td><td>EUROPE</td></tr><tr><td>BGR</td><td>1981</td><td>5.3</td><td>EUROPE</td></tr><tr><td>CYP</td><td>1981</td><td>3.1</td><td>EUROPE</td></tr><tr><td>DNK</td><td>1981</td><td>-0.7</td><td>EUROPE</td></tr><tr><td>WE</td><td>1981</td><td>1.4</td><td>EUROPE</td></tr><tr><td>EU</td><td>1981</td><td>-0.2</td><td>EUROPE</td></tr><tr><td>ITA</td><td>1981</td><td>-1.2</td><td>EUROPE</td></tr><tr><td>CHE</td><td>1981</td><td>1.6</td><td>EUROPE</td></tr><tr><td>ALB</td><td>1981</td><td>5.7</td><td>EUROPE</td></tr><tr><td>AUT</td><td>1981</td><td>-0.1</td><td>EUROPE</td></tr><tr><td>BEL</td><td>1981</td><td>-0.3</td><td>EUROPE</td></tr><tr><td>GBR</td><td>1981</td><td>-0.7</td><td>EUROPE</td></tr><tr><td>ESP</td><td>1981</td><td>-0.4</td><td>EUROPE</td></tr><tr><td>SWE</td><td>1981</td><td>4.5</td><td>EUROPE</ ...
# Databricks visualization. Run in Databricks to view.

# %%
df[df['continent'] == 'ADVANCED_ECONOMIES']
# Out:
#        index  year  gdp_growth           continent
# 53     ADVEC  1980         1.3  ADVANCED_ECONOMIES
# 281    ADVEC  1981         1.8  ADVANCED_ECONOMIES
# 509    ADVEC  1982         0.2  ADVANCED_ECONOMIES
# 737    ADVEC  1983         3.2  ADVANCED_ECONOMIES
# 965    ADVEC  1984         4.8  ADVANCED_ECONOMIES
# 1193   ADVEC  1985         3.7  ADVANCED_ECONOMIES
# 1421   ADVEC  1986         3.3  ADVANCED_ECONOMIES
# 1649   ADVEC  1987         3.8  ADVANCED_ECONOMIES
# 1877   ADVEC  1988         4.7  ADVANCED_ECONOMIES
# 2105   ADVEC  1989         4.0  ADVANCED_ECONOMIES
# 2333   ADVEC  1990         3.1  ADVANCED_ECONOMIES
# 2561   ADVEC  1991         1.6  ADVANCED_ECONOMIES
# 2789   ADVEC  1992         2.2  ADVANCED_ECONOMIES
# 3017   ADVEC  1993         1.3  ADVANCED_ECONOMIES
# 3245   ADVEC  1994         3.4  ADVANCED_ECONOMIES
# 3473   ADVEC  1995         2.9  ADVANCED_ECONOMIES
# 3701   ADVEC  1996         3.0  ADVANCED_ECONOMIES
# 3929   ADVEC  1997         3.5  ADVANCED_ECONOMIES
# 4157   ADVEC  1998         2.8  ADVANCED_ECONOMIES
# 4385   ADVEC  1999         3.6  ADVANCED_ECONOMIES
# 4613   ADVEC  2000         4.2  ADVANCED_ECONOMIES
# 4841   ADVEC  2001         1.6  ADVANCED_ECONOMIES
# 5069   ADVEC  2002         1.6  ADVANCED_ECONOMIES
# 5297   ADVEC  2003         2.0  ADVANCED_ECONOMIES
# 5525   ADVEC  2004         3.3  ADVANCED_ECONOMIES
# 5753   ADVEC  2005         2.8  ADVANCED_ECONOMIES
# 5981   ADVEC  2006         3.1  ADVANCED_ECONOMIES
# 6209   ADVEC  2007         2.8  ADVANCED_ECONOMIES
# 6437   ADVEC  2008         0.3  ADVANCED_ECONOMIES
# 6665   ADVEC  2009        -3.4  ADVANCED_ECONOMIES
# 6893   ADVEC  2010         3.1  ADVANCED_ECONOMIES
# 7121   ADVEC  2011         1.8  ADVANCED_ECONOMIES
# 7349   ADVEC  2012         1.2  ADVANCED_ECONOMIES
# 7577   ADVEC  2013         1.5  ADVANCED_ECONOMIES
# 7805   ADVEC  2014         2.1  ADVANCED_ECONOMIES
# 8033   ADVEC  2015         2.4  ADVANCED_ECONOMIES
# 8261   ADVEC  2016         1.8  ADVANCED_ECONOMIES
# 8489   ADVEC  2017         2.6  ADVANCED_ECONOMIES
# 8717   ADVEC  2018         2.3  ADVANCED_ECONOMIES
# 8945   ADVEC  2019         1.9  ADVANCED_ECONOMIES
# 9173   ADVEC  2020        -4.0  ADVANCED_ECONOMIES
# 9401   ADVEC  2021         6.0  ADVANCED_ECONOMIES
# 9629   ADVEC  2022         2.9  ADVANCED_ECONOMIES
# 9857   ADVEC  2023         1.7  ADVANCED_ECONOMIES
# 10085  ADVEC  2024         1.8  ADVANCED_ECONOMIES
# 10313  ADVEC  2025         1.8  ADVANCED_ECONOMIES
# 10541  ADVEC  2026         1.8  ADVANCED_ECONOMIES
# 10769  ADVEC  2027         1.7  ADVANCED_ECONOMIES
# 10997  ADVEC  2028         1.7  ADVANCED_ECONOMIES
# 11225  ADVEC  2029         1.7  ADVANCED_ECONOMIES

# %%
import datetime

# %%
s = datetime.datetime.now()

# %%
 pd.DataFrame.from_dict(raw['NGDP_RPCH'])
# Out:
#        SDN   SLV   EST   SWZ   FJI  FIN  ...   PIQ  SMQ  SAQ  SEQ  WEQ  WHQ
# 1980   2.5  -8.6   NaN  -3.8  -1.7  5.7  ...  -1.9  5.4  6.6  6.7  1.7  2.1
# 1981   6.3  -5.7   NaN   6.9   6.0  1.3  ...   2.7 -2.4  5.8  6.5  0.1  2.2
# 1982   4.1  -6.3   NaN   1.4  -1.1  3.1  ...   0.2 -0.5  4.1  4.2  0.8 -1.4
# 1983  -1.5   1.5   NaN  -0.5  -4.2  3.1  ...   0.8 -2.6  6.6  4.7  1.8  2.0
# 1984  -5.6   1.3   NaN   2.5  10.1  3.2  ...   4.2  4.3  4.2  4.9  2.5  6.1
# 1985  -0.6   0.6   NaN   1.9  -3.8  3.5  ...   0.9  3.5  5.6  1.7  2.7  3.8
# 1986   9.9   0.2   NaN  18.6   6.6  2.7  ...   5.6  7.1  5.0  4.9  2.7  3.5
# 1987   6.5   2.5   NaN  10.0  -7.2  3.6  ...  -0.3  3.8  4.1  6.5  3.0  3.5
# 1988   4.3   1.9   NaN   7.6   3.5  5.2  ...   3.0  1.1  8.3  8.5  4.2  3.2
# 1989   1.4   1.0   NaN   9.4  13.9  5.1  ...   4.2 -0.4  5.4  9.2  3.8  2.8
# 1990   0.8   4.8   NaN   9.9   5.8  0.2  ...   0.6 -1.1  5.4  8.4  3.2  1.5
# 1991   7.0   1.5   NaN   1.8  -2.7 -5.9  ...   4.7  4.2  2.3  7.3  2.0  1.0
# 1992   5.5   7.0   NaN   3.2   6.1 -3.3  ...  10.6  3.4  5.5  6.8  1.2  3.4
# 1993   2.8   5.8   NaN   3.1   2.6 -0.8  ...   8.9  4.6  4.4  7.8 -0.2  3.2
# 1994   3.5   4.7  -1.6   2.4   5.1  4.0  ...   8.5  4.9  6.1  7.8  2.7  4.2
# 1995   8.9   4.7   2.2   4.8   2.6  4.2  ...  -0.5  3.5  6.9  8.0  2.6  2.2
# 1996   5.5   0.8   4.9   3.8   4.8  3.7  ...   5.7  2.7  7.3  7.4  1.9  3.6
# 1997   6.1   3.1  13.1   3.1  -2.4  6.4  ...  -4.4  4.9  4.0  4.0  3.1  4.8
# 1998   8.2   2.7   4.3   2.6   1.3  5.5  ...   3.3  1.3  5.4 -7.1  3.1  4.0
# 1999   4.2   2.2  -0.4   3.0   8.7  4.4  ...   3.8 -1.4  7.6  3.4  3.0  3.4
# 2000   8.4   1.1  10.1   1.8  -1.7  5.8  ...  -2.1  3.0  4.1  5.9  4.0  4.0
# 2001  10.9   0.9   6.0   1.1   1.9  2.6  ...   0.5  0.8  4.5  3.4  2.2  0.9
# 2002   5.9   1.6   6.8   4.4   3.2  1.7  ...   1.1  0.0  3.6  5.2  1.0  1.3
# 2003   6.3   1.6   7.6   3.9   0.8  2.0  ...   6.0  2.3  7.2  5.9  1.1  2.5
# 2004   5.1   0.9   6.8   3.6   5.4  4.0  ...   2.4  7.3  7.6  6.5  2.3  4.4
# 2005   5.6   2.7   9.5   6.0  -1.3  2.8  ...   2.6  5.3  7.7  5.7  1.9  3.7
# 2006   6.5   4.3   9.8   6.0   1.9  4.0  ...   2.5  5.8  7.6  6.0  3.2  3.6
# 2007   5.7   1.9   7.6   4.4  -0.9  5.3  ...   4.7  6.8  7.2  6.6  2.8  3.1
# 2008   3.8   2.1  -5.1   0.8   1.0  0.8  ...   0.6  5.0  3.6  5.1  0.3  1.3
# 2009  -2.8  -2.1 -14.6   1.6  -1.4 -8.1  ...   3.9 -1.1  6.6  2.4 -4.3 -2.5
# 2010   3.9   2.1   2.4   3.8   3.0  3.2  ...   7.6  6.7  7.5  7.4  2.2  3.8
# 2011  -3.2   3.8   7.6   2.2   2.7  2.4  ...   2.0  5.0  5.2  4.9  1.6  2.6
# 2012 -17.0   2.8   3.7   5.4   1.4 -1.5  ...   3.4  2.6  5.4  6.1 -0.5  2.5
# 2013   2.0   2.2   1.8   3.9   4.7 -1.0  ...   3.9  3.4  6.0  5.1  0.2  2.3
# 2014   4.7   1.7   3.3   0.9   5.6 -0.5  ...  10.4  0.5  6.8  4.8  1.7  2.1
# 2015   4.9   2.4   1.8   2.2   4.5  0.5  ...   5.7 -1.0  7.3  4.9  2.2  2.0
# 2016   4.7   2.5   3.1   1.1   2.4  2.6  ...   4.8 -2.3  7.6  5.1  1.8  0.9
# 2017   0.8   2.2   5.6   2.0   5.4  3.3  ...   4.0  0.9  6.6  5.4  2.6  2.1
# 2018  -2.3   2.4   3.7   2.4   3.8  1.2  ...   0.9  0.5  6.4  5.3  1.7  2.4
# 2019  -2.5   2.4   3.7   2.7  -0.6  1.3  ...   3.1  0.0  4.1  4.7  1.6  1.8
# 2020  -3.6  -7.9  -2.9  -1.6 -17.0 -2.5  ...  -6.1 -6.3 -4.5 -3.3 -6.5 -3.7
# 2021   0.5  11.9   7.1  10.7  -4.9  2.7  ...  -1.6  7.5  8.9  3.4  6.6  6.4
# 2022  -2.5   2.8   0.1   0.5  19.8  1.5  ...   8.0  4.0  6.6  5.5  3.7  3.1
# 2023 -18.3   3.5  -3.0   4.9   7.5 -1.2  ...   4.0  1.5  7.0  4.1  0.5  2.6
# 2024 -20.3   3.0  -0.9   4.6   3.0 -0.2  ...   4.2  1.8  6.4  4.6  0.9  2.5
# 2025   8.3   3.0   1.6   4.2   3.4  2.0  ...   3.5  2.7  6.0  4.7  1.3  2.3
# 2026  13.5   2.8   2.3   3.4   3.4  1.8  ...   3.3  2.7  6.3  4.6  1.5  2.2
# 2027   6.9   2.8   2.0   2.9   3.3  1.7  ...   3.0  2.7  6.3  4.6  1.4  2.3
# 2028   5.7   2.8   2.0   2.7   3.3  1.6  ...   3.1  2.6  6.3  4.6  1.3  2.3
# 2029   4.5   2.8   2.0   2.6   3.1  1.5  ...   3.0  2.5  6.3  4.6  1.2  2.2
#
# [50 rows x 228 columns]

# %%
e = datetime.datetime.now()

# %%
e - s
# Out:
# datetime.timedelta(seconds=2, microseconds=448213)
